# %% [markdown]
# Uploading Phase:

# %%
# !pip install opencv-python
# !pip install matplotlib
# !pip install numpy
# !pip install scikit-learn
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)

# %% [markdown]
# Calling the Neccessary Libraries:

# %%
from skimage.feature import local_binary_pattern
from skimage.color import rgb2gray
from skimage import exposure
from skimage.io import imread
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import normalize
import cv2
import glob
import os

# %% [markdown]
# Finding Height and Width of an Image:

# %%
sample_image_path = '/content/drive/MyDrive/FACE IMAGES/1.1.pgm'

# Load the image in grayscale
img = cv2.imread('/content/drive/MyDrive/FACE IMAGES/1.1.pgm', cv2.IMREAD_GRAYSCALE)

# Print its shape
print("Image shape:", img.shape)

height = img.shape[0]
print("Height:", height)
# Out:
# Image shape: (80, 64)
# Height: 80

# %% [markdown]
# Training Part:

# %%
# ----------------------------
# CONFIGURATION
# ----------------------------
DATASET_PATH = "/content/drive/MyDrive/FACE IMAGES"
IMAGE_EXTENSION = ".pgm"
NUM_SUBJECTS = 250
TRAIN_PER_SUBJECT = 2
PATCH_SIZE = 5
stride = 5
target_size = (60, 80)

# LBP configurations: (R, P)
LBP_CONFIGS = [(1, 16), (2, 16), (1, 8), (2, 8)]
REFERENCE_CONFIG = (2, 16)

# ----------------------------
# FUNCTION: RIU2 Mapping
# ----------------------------
def get_riu2_mapping(P):
    table = np.zeros(2 ** P, dtype=np.uint8)
    for i in range(2 ** P):
        binary = [(i >> j) & 1 for j in range(P)]
        binary.append(binary[0])
        transitions = sum(binary[j] != binary[j+1] for j in range(P))
        if transitions <= 2:
            table[i] = sum(binary[:P])
        else:
            table[i] = P + 1
    return table

# ----------------------------
# FUNCTION: Extract LBP histogram
# ----------------------------
def extract_lbp_histogram(block, P, R, riu2_map):
    lbp = local_binary_pattern(block, P, R, method='ror').astype(np.uint16)
    lbp_mapped = riu2_map[lbp]
    hist, _ = np.histogram(
        lbp_mapped.ravel(),
        bins=np.arange(0, P + 3),
        density=True
    )
    return hist

# ----------------------------
# FUNCTION: Augment Image
# ----------------------------
def augment_image(img):
    h, w = img.shape
    aug_imgs = []

    # Rotations
    for angle in [-10, -5, 5, 10]:
        M = cv2.getRotationMatrix2D((w // 2, h // 2), angle, 1)
        rotated = cv2.warpAffine(img, M, (w, h))
        aug_imgs.append(rotated)

    # Horizontal Flip
    flipped = cv2.flip(img, 1)
    aug_imgs.append(flipped)

    # Gaussian Blur
    blurred = cv2.GaussianBlur(img, (5, 5), 0)
    aug_imgs.append(blurred)

    return aug_imgs

# ----------------------------
# PRE-COMPUTE MAPPINGS
# ----------------------------
mapping_dict = {P: get_riu2_mapping(P) for _, P in LBP_CONFIGS + [REFERENCE_CONFIG]}

# ----------------------------
# TRAINING PHASE
# ----------------------------
train_lbp_features = []
train_labels = []

for subject_id in range(1, NUM_SUBJECTS + 1):
    for sample_id in range(1, TRAIN_PER_SUBJECT + 1):
        filename = f"{subject_id}.{sample_id}{IMAGE_EXTENSION}"
        img_path = os.path.join(DATASET_PATH, filename)

        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        if img is None:
            print(f"❌ Could not load image: {filename}")
            continue

        resized = cv2.resize(img, target_size)
        augmented_images = augment_image(resized)
        augmented_images.append(resized)  # Include original

        for aug in augmented_images:
            denoised = cv2.fastNlMeansDenoising(aug, h=10)
            equalized = cv2.equalizeHist(denoised).astype(np.float64) / 255.0
            normalized = (equalized - np.mean(equalized)) / np.std(equalized)

            feature_vector = []
            for y in range(0, normalized.shape[0] - PATCH_SIZE + 1, stride):
                for x in range(0, normalized.shape[1] - PATCH_SIZE + 1, stride):
                    block = normalized[y:y + PATCH_SIZE, x:x + PATCH_SIZE]
                    combined_hist = []
                    for R, P in LBP_CONFIGS:
                        hist = extract_lbp_histogram(block, P, R, mapping_dict[P])
                        combined_hist.extend(hist)
                    feature_vector.extend(combined_hist)

            train_lbp_features.append(feature_vector)
            train_labels.append(subject_id)

        print(f"✅ Processed {filename} with {len(augmented_images)} images")

# Normalize training features
train_lbp_features = np.array(train_lbp_features, dtype=np.float32)
train_lbp_features = normalize(train_lbp_features, norm='l2')
train_labels = np.array(train_labels)

# ----------------------------
# MANHATTAN DISTANCE BASED RECOGNITION WITH VOTING
# ----------------------------
from collections import Counter

TEST_PER_SUBJECT = 2
TEST_START_INDEX = 3

test_labels = []
correct_matches = 0

total_tests = NUM_SUBJECTS * TEST_PER_SUBJECT

print("\n🗳️ Starting test phase using Voting + Manhattan distance...")

for subject_id in range(1, NUM_SUBJECTS + 1):
    for sample_offset in range(TEST_PER_SUBJECT):
        sample_id = TEST_START_INDEX + sample_offset
        filename = f"{subject_id}.{sample_id}{IMAGE_EXTENSION}"
        img_path = os.path.join(DATASET_PATH, filename)

        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        if img is None:
            print(f"❌ Could not load test image: {filename}")
            continue

        resized = cv2.resize(img, target_size)
        augmented_images = augment_image(resized)
        augmented_images.append(resized)

        predictions = []

        for aug in augmented_images:
            denoised = cv2.fastNlMeansDenoising(aug, h=10)
            equalized = cv2.equalizeHist(denoised).astype(np.float64) / 255.0
            normalized = (equalized - np.mean(equalized)) / np.std(equalized)

            feature_vector = []
            for y in range(0, normalized.shape[0] - PATCH_SIZE + 1, stride):
                for x in range(0, normalized.shape[1] - PATCH_SIZE + 1, stride):
                    block = normalized[y:y + PATCH_SIZE, x:x + PATCH_SIZE]
                    combined_hist = []
                    for R, P in LBP_CONFIGS:
                        hist = extract_lbp_histogram(block, P, R, mapping_dict[P])
                        combined_hist.extend(hist)
                    feature_vector.extend(combined_hist)

            feature_vector = np.array(feature_vector, dtype=np.float32).reshape(1, -1)
            feature_vector = normalize(feature_vector, norm='l2')

            distances = np.sum(np.abs(train_lbp_features - feature_vector), axis=1)
            best_match_idx = np.argmin(distances)
            predicted_label = train_labels[best_match_idx]
            predictions.append(predicted_label)

        final_prediction = Counter(predictions).most_common(1)[0][0]
        test_labels.append(subject_id)

        print(f"🧪 Test Image {filename} | Votes: {Counter(predictions)} | Final Prediction: {final_prediction}")

        if final_prediction == subject_id:
            correct_matches += 1

accuracy = (correct_matches / total_tests) * 100
print(f"\n✅ Final Recognition Accuracy (Voting + Manhattan): {accuracy:.2f}% ({correct_matches}/{total_tests})")
# Out:
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# ✅ Processed 1.1.pgm with 7 images
# ✅ Processed 1.2.pgm with 7 images
# ✅ Processed 2.1.pgm with 7 images
# ✅ Processed 2.2.pgm with 7 images
# ✅ Processed 3.1.pgm with 7 images
# ✅ Processed 3.2.pgm with 7 images
# ✅ Processed 4.1.pgm with 7 images
# ✅ Processed 4.2.pgm with 7 images
# ✅ Processed 5.1.pgm with 7 images
# ✅ Processed 5.2.pgm with 7 images
# ✅ Processed 6.1.pgm with 7 images
# ✅ Processed 6.2.pgm with 7 images
# ✅ Processed 7.1.pgm with 7 images
# ✅ Processed 7.2.pgm with 7 images
# ✅ Processed 8.1.pgm with 7 images
# ✅ Processed 8.2.pgm with 7 images
# ✅ Processed 9.1.pgm with 7 images
# ✅ Processed 9.2.pgm with 7 images
# ✅ Processed 10.1.pgm with 7 images
# ✅ Processed 10.2.pgm with 7 images
# ✅ Processed 11.1.pgm with 7 images
# ✅ Processed 11.2.pgm with 7 images
# ✅ Processed 12.1.pgm with 7 images
# ✅ Processed 12.2.pgm with 7 images
# ✅ Processed 13.1.pgm with 7 images
# ✅ Processed 13.2.pgm with 7 images
# ✅ Processed 14.1.pgm with 7 images
# ✅ Processed 14.2.pgm with 7 images
# ✅ Processed 15.1.pgm with 7 images
# ✅ Processed 15.2.pgm with 7 images
# ✅ Processed 16.1.pgm with 7 images
# ✅ Processed 16.2.pgm with 7 images
# ✅ Processed 17.1.pgm with 7 images
# ✅ Processed 17.2.pgm with 7 images
# ✅ Processed 18.1.pgm with 7 images
# ✅ Processed 18.2.pgm with 7 images
# ✅ Processed 19.1.pgm with 7 images
# ✅ Processed 19.2.pgm with 7 images
# ✅ Processed 20.1.pgm with 7 images
# ✅ Processed 20.2.pgm with 7 images
# ✅ Processed 21.1.pgm with 7 images
# ✅ Processed 21.2.pgm with 7 images
# ✅ Processed 22.1.pgm with 7 images
# ✅ Processed 22.2.pgm with 7 images
# ✅ Processed 23.1.pgm with 7 images
# ✅ Processed 23.2.pgm with 7 images
# ✅ Processed 24.1.pgm with 7 images
# ✅ Processed 24.2.pgm with 7 images
# ✅ Processed 25.1.pgm with 7 images
# ✅ Processed 25.2.pgm with 7 images
# ✅ Processed 26.1.pgm with 7 images
# ✅ Processed 26.2.pgm with 7 images
# ✅ Processed 27.1.pgm with 7 images
# ✅ Processed 27.2.pgm with 7 images
# ✅ Processed 28.1.pgm with 7 images
# ✅ Processed 28.2.pgm with 7 images
# ✅ Processed 29.1.pgm with 7 images
# ✅ Processed 29.2.pgm with 7 images
# ✅ Processed 30.1.pgm with 7 images
# ✅ Processed 30.2.pgm with 7 images
# ✅ Processed 31.1.pgm with 7 images
# ✅ Processed 31.2.pgm with 7 images
# ✅ Processed 32.1.pgm with 7 images
# ✅ Processed 32.2.pgm with 7 images
# ✅ Processed 33.1.pgm with 7 images
# ✅ Processed 33.2.pgm with 7 images
# ✅ Processed 34.1.pgm with 7 images
# ✅ Processed 34.2.pgm with 7 images
# ✅ Processed 35.1.pgm with 7 images
# ✅ Processed 35.2.pgm with 7 images
# ✅ Processed 36.1.pgm with 7 images
# ✅ Processed 36.2.pgm with 7 images
# ✅ Processed 37.1.pgm with 7 images
# ✅ Processed 37.2.pgm with 7 images
# ✅ Processed 38.1.pgm with 7 images
# ✅ Processed 38.2.pgm with 7 images
# ✅ Processed 39.1.pgm with 7 images
# ✅ Processed 39.2.pgm with 7 images
# ✅ Processed 40.1.pgm with 7 images
# ✅ Processed 40.2.pgm with 7 images
# ✅ Processed 41.1.pgm with 7 images
# ✅ Processed 41.2.pgm with 7 images
# ✅ Processed 42.1.pgm with 7 images
# ✅ Processed 42.2.pgm with 7 images
# ✅ Processed 43.1.pgm with 7 images
# ✅ Processed 43.2.pgm with 7 images
# ✅ Processed 44.1.pgm with 7 images
# ✅ Processed 44.2.pgm with 7 images
# ✅ Processed 45.1.pgm with 7 images
# ✅ Processed 45.2.pgm with 7 images
# ✅ Processed 46.1.pgm with 7 images
# ✅ Processed 46.2.pgm with 7 images
# ✅ Processed 47.1.pgm with 7 images
# ✅ Processed 47.2.pgm with 7 images
# ✅ Processed 48.1.pgm with 7 images
# ✅ Processed 48.2.pgm with 7 images
# ✅ Processed 49.1.pgm with 7 images
# ✅ Processed 49.2.pgm with 7 images
# ✅ Processed 50.1.pgm with 7 images
# ✅ Processed 50.2.pgm with 7 images
# ✅ Processed 51.1.pgm with 7 images
# ✅ Processed 51.2.pgm with 7 images
# ✅ Processed 52.1.pgm with 7 images
# ✅ Processed 52.2.pgm with 7 images
# ✅ Processed 53.1.pgm with 7 images
# ✅ Processed 53.2.pgm with 7 images
# ✅ Processed 54.1.pgm with 7 images
# ✅ Processed 54.2.pgm with 7 images
# ✅ Processed 55.1.pgm with 7 images
# ✅ Processed 55.2.pgm with 7 images
# ✅ Processed 56.1.pgm with 7 images
# ✅ Processed 56.2.pgm with 7 images
# ✅ Processed 57.1.pgm with 7 images
# ✅ Processed 57.2.pgm with 7 images
# ✅ Processed 58.1.pgm with 7 images
# ✅ Processed 58.2.pgm with 7 images
# ✅ Processed 59.1.pgm with 7 images
# ✅ Processed 59.2.pgm with 7 images
# ✅ Processed 60.1.pgm with 7 images
# ✅ Processed 60.2.pgm with 7 images
# ✅ Processed 61.1.pgm with 7 images
# ✅ Processed 61.2.pgm with 7 images
# ✅ Processed 62.1.pgm with 7 images
# ✅ Processed 62.2.pgm with 7 images
# ✅ Processed 63.1.pgm with 7 images
# ✅ Processed 63.2.pgm with 7 images
# ✅ Processed 64.1.pgm with 7 images
# ✅ Processed 64.2.pgm with 7 images
# ✅ Processed 65.1.pgm with 7 images
# ✅ Processed 65.2.pgm with 7 images
# ✅ Processed 66.1.pgm with 7 images
# ✅ Processed 66.2.pgm with 7 images
# ✅ Processed 67.1.pgm with 7 images
# ✅ Processed 67.2.pgm with 7 images
# ✅ Processed 68.1.pgm with 7 images
# ✅ Processed 68.2.pgm with 7 images
# ✅ Processed 69.1.pgm with 7 images
# ✅ Processed 69.2.pgm with 7 images
# ✅ Processed 70.1.pgm with 7 images
# ✅ Processed 70.2.pgm with 7 images
# ✅ Processed 71.1.pgm with 7 images
# ✅ Processed 71.2.pgm with 7 images
# ✅ Processed 72.1.pgm with 7 images
# ✅ Processed 72.2.pgm with 7 images
# ✅ Processed 73.1.pgm with 7 images
# ✅ Processed 73.2.pgm with 7 images
# ✅ Processed 74.1.pgm with 7 images
# ✅ Processed 74.2.pgm with 7 images
# ✅ Processed 75.1.pgm with 7 images
# ✅ Processed 75.2.pgm with 7 images
# ✅ Processed 76.1.pgm with 7 images
# ✅ Processed 76.2.pgm with 7 images
# ✅ Processed 77.1.pgm with 7 images
# ✅ Processed 77.2.pgm with 7 images
# ✅ Processed 78.1.pgm with 7 images
# ✅ Processed 78.2.pgm with 7 images
# ✅ Processed 79.1.pgm with 7 images
# ✅ Processed 79.2.pgm with 7 images
# ✅ Processed 80.1.pgm with 7 images
# ✅ Processed 80.2.pgm with 7 images
# ✅ Processed 81.1.pgm with 7 images
# ✅ Processed 81.2.pgm with 7 images
# ✅ Processed 82.1.pgm with 7 images
# ✅ Processed 82.2.pgm with 7 images
# ✅ Processed 83.1.pgm with 7 images
# ✅ Processed 83.2.pgm with 7 images
# ✅ Processed 84.1.pgm with 7 images
# ✅ Processed 84.2.pgm with 7 images
# ✅ Processed 85.1.pgm with 7 images
# ✅ Processed 85.2.pgm with 7 images
# ✅ Processed 86.1.pgm with 7 images
# ✅ Processed 86.2.pgm with 7 images
# ✅ Processed 87.1.pgm with 7 images
# ✅ Processed 87.2.pgm with 7 images
# ✅ Processed 88.1.pgm with 7 images
# ✅ Processed 88.2.pgm with 7 images
# ✅ Processed 89.1.pgm with 7 images
# ✅ Processed 89.2.pgm with 7 images
# ✅ Processed 90.1.pgm with 7 images
# ✅ Processed 90.2.pgm with 7 images
# ✅ Processed 91.1.pgm with 7 images
# ✅ Processed 91.2.pgm with 7 images
# ✅ Processed 92.1.pgm with 7 images
# ✅ Processed 92.2.pgm with 7 images
# ✅ Processed 93.1.pgm with 7 images
# ✅ Processed 93.2.pgm with 7 images
# ✅ Processed 94.1.pgm with 7 images
# ✅ Processed 94.2.pgm with 7 images
# ✅ Processed 95.1.pgm with 7 images
# ✅ Processed 95.2.pgm with 7 images
# ✅ Processed 96.1.pgm with 7 images
# ✅ Processed 96.2.pgm with 7 images
# ✅ Processed 97.1.pgm with 7 images
# ✅ Processed 97.2.pgm with 7 images
# ✅ Processed 98.1.pgm with 7 images
# ✅ Processed 98.2.pgm with 7 images
# ✅ Processed 99.1.pgm with 7 images
# ✅ Processed 99.2.pgm with 7 images
# ✅ Processed 100.1.pgm with 7 images
# ✅ Processed 100.2.pgm with 7 images
# ✅ Processed 101.1.pgm with 7 images
# ✅ Processed 101.2.pgm with 7 images
# ✅ Processed 102.1.pgm with 7 images
# ✅ Processed 102.2.pgm with 7 images
# ✅ Processed 103.1.pgm with 7 images
# ✅ Processed 103.2.pgm with 7 images
# ✅ Processed 104.1.pgm with 7 images
# ✅ Processed 104.2.pgm with 7 images
# ✅ Processed 105.1.pgm with 7 images
# ✅ Processed 105.2.pgm with 7 images
# ✅ Processed 106.1.pgm with 7 images
# ✅ Processed 106.2.pgm with 7 images
# ✅ Processed 107.1.pgm with 7 images
# ✅ Processed 107.2.pgm with 7 images
# ✅ Processed 108.1.pgm with 7 images
# ✅ Processed 108.2.pgm with 7 images
# ✅ Processed 109.1.pgm with 7 images
# ✅ Processed 109.2.pgm with 7 images
# ✅ Processed 110.1.pgm with 7 images
# ✅ Processed 110.2.pgm with 7 images
# ✅ Processed 111.1.pgm with 7 images
# ✅ Processed 111.2.pgm with 7 images
# ✅ Processed 112.1.pgm with 7 images
# ✅ Processed 112.2.pgm with 7 images
# ✅ Processed 113.1.pgm with 7 images
# ✅ Processed 113.2.pgm with 7 images
# ✅ Processed 114.1.pgm with 7 images
# ✅ Processed 114.2.pgm with 7 images
# ✅ Processed 115.1.pgm with 7 images
# ✅ Processed 115.2.pgm with 7 images
# ✅ Processed 116.1.pgm with 7 images
# ✅ Processed 116.2.pgm with 7 images
# ✅ Processed 117.1.pgm with 7 images
# ✅ Processed 117.2.pgm with 7 images
# ✅ Processed 118.1.pgm with 7 images
# ✅ Processed 118.2.pgm with 7 images
# ✅ Processed 119.1.pgm with 7 images
# ✅ Processed 119.2.pgm with 7 images
# ✅ Processed 120.1.pgm with 7 images
# ✅ Processed 120.2.pgm with 7 images
# ✅ Processed 121.1.pgm with 7 images
# ✅ Processed 121.2.pgm with 7 images
# ✅ Processed 122.1.pgm with 7 images
# ✅ Processed 122.2.pgm with 7 images
# ✅ Processed 123.1.pgm with 7 images
# ✅ Processed 123.2.pgm with 7 images
# ✅ Processed 124.1.pgm with 7 images
# ✅ Processed 124.2.pgm with 7 images
# ✅ Processed 125.1.pgm with 7 images
# ✅ Processed 125.2.pgm with 7 images
# ✅ Processed 126.1.pgm with 7 images
# ✅ Processed 126.2.pgm with 7 images
# ✅ Processed 127.1.pgm with 7 images
# ✅ Processed 127.2.pgm with 7 images
# ✅ Processed 128.1.pgm with 7 images
# ✅ Processed 128.2.pgm with 7 images
# ✅ Processed 129.1.pgm with 7 images
# ✅ Processed 129.2.pgm with 7 images
# ✅ Processed 130.1.pgm with 7 images
# ✅ Processed 130.2.pgm with 7 images
# ✅ Processed 131.1.pgm with 7 images
# ✅ Processed 131.2.pgm with 7 images
# ✅ Processed 132.1.pgm with 7 images
# ✅ Processed 132.2.pgm with 7 images
# ✅ Processed 133.1.pgm with 7 images
# ✅ Processed 133.2.pgm with 7 images
# ✅ Processed 134.1.pgm with 7 images
# ✅ Processed 134.2.pgm with 7 images
# ✅ Processed 135.1.pgm with 7 images
# ✅ Processed 135.2.pgm with 7 images
# ✅ Processed 136.1.pgm with 7 images
# ✅ Processed 136.2.pgm with 7 images
# ✅ Processed 137.1.pgm with 7 images
# ✅ Processed 137.2.pgm with 7 images
# ✅ Processed 138.1.pgm with 7 images
# ✅ Processed 138.2.pgm with 7 images
# ✅ Processed 139.1.pgm with 7 images
# ✅ Processed 139.2.pgm with 7 images
# ✅ Processed 140.1.pgm with 7 images
# ✅ Processed 140.2.pgm with 7 images
# ✅ Processed 141.1.pgm with 7 images
# ✅ Processed 141.2.pgm with 7 images
# ✅ Processed 142.1.pgm with 7 images
# ✅ Processed 142.2.pgm with 7 images
# ✅ Processed 143.1.pgm with 7 images
# ✅ Processed 143.2.pgm with 7 images
# ✅ Processed 144.1.pgm with 7 images
# ✅ Processed 144.2.pgm with 7 images
# ✅ Processed 145.1.pgm with 7 images
# ✅ Processed 145.2.pgm with 7 images
# ✅ Processed 146.1.pgm with 7 images
# ✅ Processed 146.2.pgm with 7 images
# ✅ Processed 147.1.pgm with 7 images
# ✅ Processed 147.2.pgm with 7 images
# ✅ Processed 148.1.pgm with 7 images
# ✅ Processed 148.2.pgm with 7 images
# ✅ Processed 149.1.pgm with 7 images
# ✅ Processed 149.2.pgm with 7 images
# ✅ Processed 150.1.pgm with 7 images
# ✅ Processed 150.2.pgm with 7 images
# ✅ Processed 151.1.pgm with 7 images
# ✅ Processed 151.2.pgm with 7 images
# ✅ Processed 152.1.pgm with 7 images
# ✅ Processed 152.2.pgm with 7 images
# ✅ Processed 153.1.pgm with 7 images
# ✅ Processed 153.2.pgm with 7 images
# ✅ Processed 154.1.pgm with 7 images
# ✅ Processed 154.2.pgm with 7 images
# ✅ Processed 155.1.pgm with 7 images
# ✅ Processed 155.2.pgm with 7 images
# ✅ Processed 156.1.pgm with 7 images
# ✅ Processed 156.2.pgm with 7 images
# ✅ Processed 157.1.pgm with 7 images
# ✅ Processed 157.2.pgm with 7 images
# ✅ Processed 158.1.pgm with 7 images
# ✅ Processed 158.2.pgm with 7 images
# ✅ Processed 159.1.pgm with 7 images
# ✅ Processed 159.2.pgm with 7 images
# ✅ Processed 160.1.pgm with 7 images
# ✅ Processed 160.2.pgm with 7 images
# ✅ Processed 161.1.pgm with 7 images
# ✅ Processed 161.2.pgm with 7 images
# ✅ Processed 162.1.pgm with 7 images
# ✅ Processed 162.2.pgm with 7 images
# ✅ Processed 163.1.pgm with 7 images
# ✅ Processed 163.2.pgm with 7 images
# ✅ Processed 164.1.pgm with 7 images
# ✅ Processed 164.2.pgm with 7 images
# ✅ Processed 165.1.pgm with 7 images
# ✅ Processed 165.2.pgm with 7 images
# ✅ Processed 166.1.pgm with 7 images
# ✅ Processed 166.2.pgm with 7 images
# ✅ Processed 167.1.pgm with 7 images
# ✅ Processed 167.2.pgm with 7 images
# ✅ Processed 168.1.pgm with 7 images
# ✅ Processed 168.2.pgm with 7 images
# ✅ Processed 169.1.pgm with 7 images
# ✅ Processed 169.2.pgm with 7 images
# ✅ Processed 170.1.pgm with 7 images
# ✅ Processed 170.2.pgm with 7 images
# ✅ Processed 171.1.pgm with 7 images
# ✅ Processed 171.2.pgm with 7 images
# ✅ Processed 172.1.pgm with 7 images
# ✅ Processed 172.2.pgm with 7 images
# ✅ Processed 173.1.pgm with 7 images
# ✅ Processed 173.2.pgm with 7 images
# ✅ Processed 174.1.pgm with 7 images
# ✅ Processed 174.2.pgm with 7 images
# ✅ Processed 175.1.pgm with 7 images
# ✅ Processed 175.2.pgm with 7 images
# ✅ Processed 176.1.pgm with 7 images
# ✅ Processed 176.2.pgm with 7 images
# ✅ Processed 177.1.pgm with 7 images
# ✅ Processed 177.2.pgm with 7 images
# ✅ Processed 178.1.pgm with 7 images
# ✅ Processed 178.2.pgm with 7 images
# ✅ Processed 179.1.pgm with 7 images
# ✅ Processed 179.2.pgm with 7 images
# ✅ Processed 180.1.pgm with 7 images
# ✅ Processed 180.2.pgm with 7 images
# ✅ Processed 181.1.pgm with 7 images
# ✅ Processed 181.2.pgm with 7 images
# ✅ Processed 182.1.pgm with 7 images
# ✅ Processed 182.2.pgm with 7 images
# ✅ Processed 183.1.pgm with 7 images
# ✅ Processed 183.2.pgm with 7 images
# ✅ Processed 184.1.pgm with 7 images
# ✅ Processed 184.2.pgm with 7 images
# ✅ Processed 185.1.pgm with 7 images
# ✅ Processed 185.2.pgm with 7 images
# ✅ Processed 186.1.pgm with 7 images
# ✅ Processed 186.2.pgm with 7 images
# ✅ Processed 187.1.pgm with 7 images
# ✅ Processed 187.2.pgm with 7 images
# ✅ Processed 188.1.pgm with 7 images
# ✅ Processed 188.2.pgm with 7 images
# ✅ Processed 189.1.pgm with 7 images
# ✅ Processed 189.2.pgm with 7 images
# ✅ Processed 190.1.pgm with 7 images
# ✅ Processed 190.2.pgm with 7 images
# ✅ Processed 191.1.pgm with 7 images
# ✅ Processed 191.2.pgm with 7 images
# ✅ Processed 192.1.pgm with 7 images
# ✅ Processed 192.2.pgm with 7 images
# ✅ Processed 193.1.pgm with 7 images
# ✅ Processed 193.2.pgm with 7 images
# ✅ Processed 194.1.pgm with 7 images
# ✅ Processed 194.2.pgm with 7 images
# ✅ Processed 195.1.pgm with 7 images
# ✅ Processed 195.2.pgm with 7 images
# ✅ Processed 196.1.pgm with 7 images
# ✅ Processed 196.2.pgm with 7 images
# ✅ Processed 197.1.pgm with 7 images
# ✅ Processed 197.2.pgm with 7 images
# ✅ Processed 198.1.pgm with 7 images
# ✅ Processed 198.2.pgm with 7 images
# ✅ Processed 199.1.pgm with 7 images
# ✅ Processed 199.2.pgm with 7 images
# ✅ Processed 200.1.pgm with 7 images
# ✅ Processed 200.2.pgm with 7 images
# ✅ Processed 201.1.pgm with 7 images
# ✅ Processed 201.2.pgm with 7 images
# ✅ Processed 202.1.pgm with 7 images
# ✅ Processed 202.2.pgm with 7 images
# ✅ Processed 203.1.pgm with 7 images
# ✅ Processed 203.2.pgm with 7 images
# ✅ Processed 204.1.pgm with 7 images
# ✅ Processed 204.2.pgm with 7 images
# ✅ Processed 205.1.pgm with 7 images
# ✅ Processed 205.2.pgm with 7 images
# ✅ Processed 206.1.pgm with 7 images
# ✅ Processed 206.2.pgm with 7 images
# ✅ Processed 207.1.pgm with 7 images
# ✅ Processed 207.2.pgm with 7 images
# ✅ Processed 208.1.pgm with 7 images
# ✅ Processed 208.2.pgm with 7 images
# ✅ Processed 209.1.pgm with 7 images
# ✅ Processed 209.2.pgm with 7 images
# ✅ Processed 210.1.pgm with 7 images
# ✅ Processed 210.2.pgm with 7 images
# ✅ Processed 211.1.pgm with 7 images
# ✅ Processed 211.2.pgm with 7 images
# ✅ Processed 212.1.pgm with 7 images
# ✅ Processed 212.2.pgm with 7 images
# ✅ Processed 213.1.pgm with 7 images
# ✅ Processed 213.2.pgm with 7 images
# ✅ Processed 214.1.pgm with 7 images
# ✅ Processed 214.2.pgm with 7 images
# ✅ Processed 215.1.pgm with 7 images
# ✅ Processed 215.2.pgm with 7 images
# ✅ Processed 216.1.pgm with 7 images
# ✅ Processed 216.2.pgm with 7 images
# ✅ Processed 217.1.pgm with 7 images
# ✅ Processed 217.2.pgm with 7 images
# ✅ Processed 218.1.pgm with 7 images
# ✅ Processed 218.2.pgm with 7 images
# ✅ Processed 219.1.pgm with 7 images
# ✅ Processed 219.2.pgm with 7 images
# ✅ Processed 220.1.pgm with 7 images
# ✅ Processed 220.2.pgm with 7 images
# ✅ Processed 221.1.pgm with 7 images
# ✅ Processed 221.2.pgm with 7 images
# ✅ Processed 222.1.pgm with 7 images
# ✅ Processed 222.2.pgm with 7 images
# ✅ Processed 223.1.pgm with 7 images
# ✅ Processed 223.2.pgm with 7 images
# ✅ Processed 224.1.pgm with 7 images
# ✅ Processed 224.2.pgm with 7 images
# ✅ Processed 225.1.pgm with 7 images
# ✅ Processed 225.2.pgm with 7 images
# ✅ Processed 226.1.pgm with 7 images
# ✅ Processed 226.2.pgm with 7 images
# ✅ Processed 227.1.pgm with 7 images
# ✅ Processed 227.2.pgm with 7 images
# ✅ Processed 228.1.pgm with 7 images
# ✅ Processed 228.2.pgm with 7 images
# ✅ Processed 229.1.pgm with 7 images
# ✅ Processed 229.2.pgm with 7 images
# ✅ Processed 230.1.pgm with 7 images
# ✅ Processed 230.2.pgm with 7 images
# ✅ Processed 231.1.pgm with 7 images
# ✅ Processed 231.2.pgm with 7 images
# ✅ Processed 232.1.pgm with 7 images
# ✅ Processed 232.2.pgm with 7 images
# ✅ Processed 233.1.pgm with 7 images
# ✅ Processed 233.2.pgm with 7 images
# ✅ Processed 234.1.pgm with 7 images
# ✅ Processed 234.2.pgm with 7 images
# ✅ Processed 235.1.pgm with 7 images
# ✅ Processed 235.2.pgm with 7 images
# ✅ Processed 236.1.pgm with 7 images
# ✅ Processed 236.2.pgm with 7 images
# ✅ Processed 237.1.pgm with 7 images
# ✅ Processed 237.2.pgm with 7 images
# ✅ Processed 238.1.pgm with 7 images
# ✅ Processed 238.2.pgm with 7 images
# ✅ Processed 239.1.pgm with 7 images
# ✅ Processed 239.2.pgm with 7 images
# ✅ Processed 240.1.pgm with 7 images
# ✅ Processed 240.2.pgm with 7 images
# ✅ Processed 241.1.pgm with 7 images
# ✅ Processed 241.2.pgm with 7 images
# ✅ Processed 242.1.pgm with 7 images
# ✅ Processed 242.2.pgm with 7 images
# ✅ Processed 243.1.pgm with 7 images
# ✅ Processed 243.2.pgm with 7 images
# ✅ Processed 244.1.pgm with 7 images
# ✅ Processed 244.2.pgm with 7 images
# ✅ Processed 245.1.pgm with 7 images
# ✅ Processed 245.2.pgm with 7 images
# ✅ Processed 246.1.pgm with 7 images
# ✅ Processed 246.2.pgm with 7 images
# ✅ Processed 247.1.pgm with 7 images
# ✅ Processed 247.2.pgm with 7 images
# ✅ Processed 248.1.pgm with 7 images
# ✅ Processed 248.2.pgm with 7 images
# ✅ Processed 249.1.pgm with 7 images
# ✅ Processed 249.2.pgm with 7 images
# ✅ Processed 250.1.pgm with 7 images
# ✅ Processed 250.2.pgm with 7 images
#
# 🗳️ Starting test phase using Voting + Manhattan distance...
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# 🧪 Test Image 1.3.pgm | Votes: Counter({np.int64(1): 6, np.int64(10): 1}) | Final Prediction: 1
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# 🧪 Test Image 1.4.pgm | Votes: Counter({np.int64(1): 7}) | Final Prediction: 1
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# 🧪 Test Image 2.3.pgm | Votes: Counter({np.int64(2): 7}) | Final Prediction: 2
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# 🧪 Test Image 2.4.pgm | Votes: Counter({np.int64(2): 6, np.int64(137): 1}) | Final Prediction: 2
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# 🧪 Test Image 3.3.pgm | Votes: Counter({np.int64(3): 7}) | Final Prediction: 3
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# 🧪 Test Image 3.4.pgm | Votes: Counter({np.int64(3): 7}) | Final Prediction: 3
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# 🧪 Test Image 4.3.pgm | Votes: Counter({np.int64(4): 7}) | Final Prediction: 4
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# 🧪 Test Image 4.4.pgm | Votes: Counter({np.int64(4): 7}) | Final Prediction: 4
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# 🧪 Test Image 5.3.pgm | Votes: Counter({np.int64(5): 7}) | Final Prediction: 5
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# 🧪 Test Image 5.4.pgm | Votes: Counter({np.int64(5): 7}) | Final Prediction: 5
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# 🧪 Test Image 6.3.pgm | Votes: Counter({np.int64(6): 7}) | Final Prediction: 6
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# 🧪 Test Image 6.4.pgm | Votes: Counter({np.int64(6): 7}) | Final Prediction: 6
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# ...
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# 🧪 Test Image 247.4.pgm | Votes: Counter({np.int64(247): 7}) | Final Prediction: 247
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# 🧪 Test Image 248.3.pgm | Votes: Counter({np.int64(248): 7}) | Final Prediction: 248
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# 🧪 Test Image 248.4.pgm | Votes: Counter({np.int64(248): 7}) | Final Prediction: 248
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# 🧪 Test Image 249.3.pgm | Votes: Counter({np.int64(249): 7}) | Final Prediction: 249
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# 🧪 Test Image 249.4.pgm | Votes: Counter({np.int64(249): 7}) | Final Prediction: 249
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# 🧪 Test Image 250.3.pgm | Votes: Counter({np.int64(250): 7}) | Final Prediction: 250
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# 🧪 Test Image 250.4.pgm | Votes: Counter({np.int64(250): 7}) | Final Prediction: 250
#
# ✅ Final Recognition Accuracy (Voting + Manhattan): 96.80% (484/500)
# /usr/local/lib/python3.11/dist-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
